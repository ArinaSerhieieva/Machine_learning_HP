# %% [markdown]
# У цьому домашньому завданні ми будемо працювати з набором даних Tips. Нижче інформація про нього.
#
# **Про датасет:**
#
# Tips - це датасет, який містить інформацію про рахунки та чайові в ресторані.
#
# **Колонки датасету:**
# - `total_bill` - загальна сума рахунку (долари)
# - `tip` - розмір чайових (долари)
# - `sex` - стать відвідувача (Male/Female)
# - `smoker` - чи курить (Yes/No)
# - `day` - день тижня (Thur/Fri/Sat/Sun)
# - `time` - час відвідування (Lunch/Dinner)
# - `size` - розмір групи (кількість людей)
#
# **Джерело:** Оригінальні дані зібрані в одному з американських ресторанів у 1990-х роках. Скачати і переглянути набір даних можна тут: https://www.kaggle.com/datasets/sakshisatre/tips-dataset
#
# А також ми вже вивантажили файл з даними і завантажили вам у Матеріали до цього модуля.

# %% [markdown]
# **1. Завантаження та огляд**
#
# Завантажте датасет Tips (Чайові) з файла у матеріалах `tips.csv`.
#
# Виведіть (кожен пункт оцінюється в 0.5 бала):
# - Перші 5 рядків
# - Розмір датасету (shape)
# - Назви всіх колонок
# - Інформацію про типи даних (info)

# %%
import pandas as pd

# %%
df = pd.read_csv('tip_dataset.csv')

# %%
display(df.head())   #1.1 Перші 5 рядків
display(df.shape)   #1.2 Розмір датасету (shape)
display(df.columns)  #1.3 Всі колонки
display(df.info())   #1.4 Інформацію про типи даних
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# (244, 7)
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None

# %% [markdown]
# **2. Базова вибірка даних**
#
# Виберіть та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Колонку `total_bill` (загальний рахунок)
# - Колонки `total_bill` та `tip` (чайові) разом
# - Перші 10 рядків
# - Рядок з індексом 5

# %%
#2.1 Колонку total_bill (загальний рахунок)
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
#2.2 Колонку total_bill та tip (чайові) разом
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#2.3 Рядок з індексом 5
df.loc[0:9]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
#2.4 Перші 10 рядків
df.iloc[5]
# Out:
# total_bill     25.29
# tip             4.71
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 5, dtype: object

# %% [markdown]
# **3. Фільтрація даних**
#
# Відфільтруйте повний набір даних та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Всі рахунки більше 20 доларів (`total_bill > 20`)
# - Всі відвідувачі-жінки (`sex == 'Female'`)
# - Рахунки на вечерю (`time == 'Dinner'`)
# - Рахунки на вечерю з сумою чеку більше 30 доларів
#
# Для виведення результатів фільтрації:
# - зберегти результат у окрему змінну
# - показати кількість записів у відфільтрованому наборі
# - вивести перші 5 записів відфільтрованого набору.

# %%
# 3.1 Всі рахунки більше 20 доларів (total_bill > 20)

df_bill_gte20=df[(df['total_bill']>=20)]
display(df_bill_gte20.shape)
display(df_bill_gte20.head())
# Out:
# (97, 7)
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
# 3.2 Всі відвідувачі-жінки (sex == 'Female')
df_women = df[(df['sex'] == 'Female')]
display(df_women.shape)
display(df_women.head())
# Out:
# (87, 7)
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
#3.3 Рахунки на вечерю (time == 'Dinner')
df_dinner_bills = df[(df['time'] == 'Dinner')]
display(df_dinner_bills.shape)
display(df_dinner_bills.head())
# Out:
# (176, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 3.4 Рахунки на вечерю з сумою чеку більше 30 доларів
df_dinner_bills_gte_30 = df[(df['time'] == 'Dinner') & (df['total_bill'] >= 30)]
display(df_dinner_bills_gte_30.shape)
display(df_dinner_bills_gte_30.head())
# Out:
# (27, 7)
#     total_bill   tip     sex smoker  day    time  size
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 23       39.42  7.58    Male     No  Sat  Dinner     4
# 39       31.27  5.00    Male     No  Sat  Dinner     3
# 44       30.40  5.60    Male     No  Sun  Dinner     4
# 47       32.40  6.00    Male     No  Sun  Dinner     4

# %% [markdown]
# ---
#
# **4. Описова статистика**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній розмір рахунку на всьому наборі даних
# - Максимальні чайові
# - Кількість пропущених значень у всіх колонках
# - Скільки в наборі даних рахунків за обіди і за вечері

# %%
# 4.1 Середній розмір рахунку на всьому наборі даних
df_avg_bill = df['total_bill'].mean()
df_avg_bill
# Out:
# np.float64(19.78594262295082)

# %%
# 4.2 Максимальні чайові
df_max_bill = df['tip'].max()
df_max_bill
# Out:
# 10.0

# %%
# 4.3 Кількість пропущених значень у всіх колонках
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#4.4a Скільки в наборі даних рахунків за обіди і за вечері
df.groupby(['time']).size()
# Out:
# time
# Dinner    176
# Lunch      68
# dtype: int64

# %%
#4.4b Скільки в наборі даних рахунків за обіди і за вечері
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# **5. Статистика із групуванням**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній рахунок за статтю (groupby `sex`)
# - Середні чайові за днем тижня (groupby `day`)
# - Скільки відвідувачів у кожен день

# %%
#5.1 Середній рахунок за статтю (groupby sex)

display(df.groupby('sex')['total_bill'].agg(['mean']))
display(df.groupby('sex')['total_bill'].mean())
# Out:
#              mean
# sex
# Female  18.056897
# Male    20.744076
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
#5.2  Середні чайові за днем тижня (groupby day)

display(df.groupby('day')['tip'].agg(['mean']))
df.groupby('day')['tip'].mean()
# Out:
#           mean
# day
# Fri   2.734737
# Sat   2.993103
# Sun   3.255132
# Thur  2.771452
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
#5.3 Скільки відвідувачів у кожен день
df.groupby('day')['size'].sum()
# Out:
# day
# Fri      40
# Sat     219
# Sun     216
# Thur    152
# Name: size, dtype: int64

# %% [markdown]
# ---
#
# **6. Створення нової колонки**
#
# Створіть нову колонку `tip_percentage` - відсоток чайових від загальної суми рахунку.
# Виведіть перші 10 рядків з новою колонкою.

# %%
df['tip_percentage'] = df['tip'] / df['total_bill'] # щоб отримати в відсотках домножити на 100
df['tip_percentage'].head(10)
# Out:
# 0    0.059447
# 1    0.160542
# 2    0.166587
# 3    0.139780
# 4    0.146808
# 5    0.186240
# 6    0.228050
# 7    0.116071
# 8    0.130319
# 9    0.218539
# Name: tip_percentage, dtype: float64

# %% [markdown]
# ---
#
# **7. Сортування**
#
# Відсортуйте датасет і виведіть результат сортування в кожному випадку окремо (кожен пункт оцінюється в 0.5 бала):
# - За розміром рахунку (зростання)
# - За чайовими (спадання)
#
# Додатково виведіть топ-5 найбільших чайових використовуючи метод `nlargest`.

# %%
#7.1 Сортування за розміром рахунку (зростання)
df.sort_values(['total_bill'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percentage
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1        0.325733
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2        0.173913
# 111        7.25   1.00  Female     No   Sat  Dinner     1        0.137931
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2        0.710345
# 149        7.51   2.00    Male     No  Thur   Lunch     2        0.266312
# ..          ...    ...     ...    ...   ...     ...   ...             ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3        0.077178
# 156       48.17   5.00    Male     No   Sun  Dinner     6        0.103799
# 59        48.27   6.73    Male     No   Sat  Dinner     4        0.139424
# 212       48.33   9.00    Male     No   Sat  Dinner     4        0.186220
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3        0.196812
#
# [244 rows x 8 columns]

# %%
#7.2 Сортування за чайовими (спадання)
df.sort_values(['tip'], ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percentage
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3        0.196812
# 212       48.33   9.00    Male     No   Sat  Dinner     4        0.186220
# 23        39.42   7.58    Male     No   Sat  Dinner     4        0.192288
# 59        48.27   6.73    Male     No   Sat  Dinner     4        0.139424
# 141       34.30   6.70    Male     No  Thur   Lunch     6        0.195335
# ..          ...    ...     ...    ...   ...     ...   ...             ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2        0.059447
# 111        7.25   1.00  Female     No   Sat  Dinner     1        0.137931
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2        0.173913
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1        0.325733
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2        0.079365
#
# [244 rows x 8 columns]

# %%
# топ-5 найбільших чайових використовуючи метод
df.nlargest(5, 'tip')['tip']
# Out:
# 170    10.00
# 212     9.00
# 23      7.58
# 59      6.73
# 141     6.70
# Name: tip, dtype: float64
